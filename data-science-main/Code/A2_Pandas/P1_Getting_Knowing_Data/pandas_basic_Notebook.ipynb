# %% [markdown]
# # Getting and Knowing Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 1 : Import Dataset

# %%
df = pd.read_csv("chipotle.tsv", sep = "\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# Note : NaN (Not a number) : null value

# %% [markdown]
# # Step Dataset overview

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Note: So sánh số giá trị non-null với tổng data (tổng hàng) để xem feature nào bị null để clean
#
# Với các kiểu khác int và float như String , .. đều tính là object

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Note : Liệt kê tất cả các feature(các cột)

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# Note : chỉ có thể liệt kê ra cá feature mà không phải object nên chỉ có 2 feature

# %%
df.describe(include ="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# Note : Include all kể các object

# %%
df.loc[df['quantity'] == 15]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %%
df.loc[df.quantity == 15]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %% [markdown]
# Note : loc như 1 dạng filter, như ở ví dụ trên nó sẽ trả về chỗ mà có quantity bằng 15
#
# Có 2 cách để lấy giá trị feature như 2 cell trên

# %%
df.loc[(df.quantity > 12) | (df.item_name == "Chips and Fresh Tomato Salsa")]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %% [markdown]
# Note : or : | chứ không phải là  ||

# %%
df.loc[(df.quantity > 12) & (df.item_name == "Chips and Fresh Tomato Salsa")]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %%
df.loc[(df.quantity > 12) & (df.item_name == "Chips and Fresh Tomato Salsa"), ['order_id', 'quantity']]
# Out:
#       order_id  quantity
# 3598      1443        15

# %% [markdown]
# Note : biến số thứ 2 là 1 list chứa các features muốn được filter

# %%
df.loc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %% [markdown]
# Note: tìm kiếm theo index , bắt đầu từ 0 đến n-1

# %%
df.iloc[[0]]
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#   item_price
# 0     $2.39

# %% [markdown]
# NOTE : Hiển thị theo dạng DataFrame, chỉ cần thêm nếu chỉ cần lấy 1 hàng

# %%
df.iloc[3 : 10]
# Out:
#    order_id  quantity                              item_name  \
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# ...

# %% [markdown]
# NOTE : Viết kiểu này sẽ chạy từ a - 1 -> n - 1

# %%
df.iloc[3 : 10, 0 : -1]
# Out:
#    order_id  quantity                              item_name  \
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                NaN
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...

# %% [markdown]
# NOTE : slice cut => a : b  -> lấy từ a đến b - 1

# %% [markdown]
# # Data Manipulation

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# NOTE :
#     'b'       boolean
#     'i'       (signed) integer
#     'u'       unsigned integer
#     'f'       floating-point
#     'c'       complex-floating point
#     'O'       (Python) objects
#     'S', 'a'  (byte-)string
#     'U'       Unicode
#     'V'       raw data (void)

# %% [markdown]
# # Apply()

# %%
df.item_price.apply(lambda x : x.replace('$', ''))
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %% [raw]
# NOTE : Loại bỏ Đô la của label, đưa định dạng về float

# %% [raw]
# df.apply(func, axis=0)
# func: Là hàm mà bạn muốn áp dụng cho mỗi phần tử hoặc cột.
# axis: Được sử dụng để xác định liệu bạn muốn áp dụng hàm theo cột (axis=0) hay theo hàng (axis=1).

# %%
X = df.item_price.apply(lambda x : x.replace('$', ''))
X.dtype
# Out:
# dtype('O')

# %%
X = df.item_price.apply(lambda x : float(x.replace('$', '')))
X.dtype
# Out:
# dtype('float64')

# %%
df.item_price = X

# %% [raw]
# Chuyển dữ liệu vừa xử lí thay thế cho dữ liệu cũ trong bảng

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ###Tạo cột mới

# %%
#df.total_price = df.item_price * df.quantity
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8268\4101891353.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.total_price = df.item_price * df.quantity

# %% [raw]
# Nếu tạo cột mới thì cách này là sai vì sẽ dẫn đến lỗi này :  UserWarning: Pandas doesn't allow columns to be created via a new attribute name

# %%
df['total_price'] = df['item_price'] * df['quantity']

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %% [markdown]
# # How much was the revenue for the period in the datasheet?

# %%
sum_price = df.total_price.sum()
print(sum_price)
# Out:
# 39237.02

# %% [raw]
# Tổng doanh thu trong dataset

# %% [markdown]
# # Sản phẩm nào được mua nhiều nhất ( What was the most odered item ?)

# %% [markdown]
# # Group By

# %%
df.groupby("item_name")

# %%
df.groupby("item_name").apply(print)
# Out:
#       order_id  quantity          item_name choice_description  item_price  \
# 298        129         1  6 Pack Soft Drink           [Sprite]        6.49
# 341        148         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 357        154         1  6 Pack Soft Drink             [Coke]        6.49
# 388        168         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 417        182         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 553        230         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 639        264         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 721        298         1  6 Pack Soft Drink           [Nestea]        6.49
# 743        306         1  6 Pack Soft Drink             [Coke]        6.49
# 879        363         1  6 Pack Soft Drink             [Coke]        6.49
# 1026       422         1  6 Pack Soft Drink           [Sprite]        6.49
# ...

# %% [raw]
# nhóm những sản phẩm có tên chung giống nhau lại

# %%
df.groupby("item_name")['quantity'].apply(print)
# Out:
# 298     1
# 341     1
# 357     1
# 388     1
# 417     1
# 553     1
# 639     1
# 721     1
# 743     1
# 879     1
# 1026    1
# 1051    1
# 1124    1
# 1167    1
# 1260    1
# 1279    1
# 1392    1
# 1755    1
# 1758    1
# 1849    1
# 1860    1
# 1916    1
# 1922    1
# 1937    1
# 1976    1
# 2108    1
# 2232    1
# 2374    1
# 2389    1
# 2713    1
# 2793    1
# 2860    1
# 3010    1
# 3132    1
# 3141    1
# 3389    2
# 3422    1
# 3600    1
# 3614    1
# 3633    1
# 3693    1
# 3766    1
# 3789    1
# 3806    1
# 3836    1
# 3875    1
# 3886    1
# 4169    1
# 4174    1
# 4359    1
# 4363    1
# 4522    1
# 4527    1
# 4535    1
# Name: 6 Pack Soft Drink, dtype: int64
# 39      1
# 58      1
# 95      1
# 115     1
# 127     1
#        ..
# 4380    1
# 4441    1
# 4485    1
# 4510    1
# 4594    1
# Name: Barbacoa Bowl, Length: 66, dtype: int64
# 21      1
# 81      1
# 121     1
# 130     1
# 144     1
#        ..
# 4355    1
# 4358    1
# 4592    1
# 4602    1
# 4603    1
# ...

# %% [raw]
# chỉ in ra quantity

# %%
df.groupby("item_name")['quantity'].sum()
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
df.groupby("item_name")['quantity'].sum().sort_values(ascending = False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
print(df.groupby("item_name")['quantity'].sum().idxmax(), df.groupby("item_name")['quantity'].sum().max())
# Out:
# Chicken Bowl 761

# %% [markdown]
# # Uniqe value

# %% [raw]
# Số data khác nhau trong feature

# %%
df.item_name.value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [raw]
# Số món hàng khác nhau được bán ra và số lượng bán

# %%
df.item_name.value_counts().count()
# Out:
# 50

# %% [raw]
# Tổng số món khác nhau được bán ra

# %%
df.item_name.nunique()
# Out:
# 50
